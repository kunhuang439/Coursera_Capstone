# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import requests

# %%
url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

r = requests.get(url, headers=header)

tables = pd.read_html(r.text)

df=pd.DataFrame(tables[0])

# %%
df.columns=['Postal Code','Borough','Neighbourhood']

df.drop([0],axis=0,inplace=True)

df.reset_index()
# Out:
#      index Postal Code           Borough  \
# 0        1         M2A      Not assigned
# 1        2         M3A        North York
# 2        3         M4A        North York
# 3        4         M5A  Downtown Toronto
# 4        5         M6A        North York
# 5        6         M6A        North York
# 6        7         M7A  Downtown Toronto
# 7        8         M8A      Not assigned
# 8        9         M9A      Queen's Park
# 9       10         M1B       Scarborough
# 10      11         M1B       Scarborough
# 11      12         M2B      Not assigned
# 12      13         M3B        North York
# 13      14         M4B         East York
# 14      15         M4B         East York
# 15      16         M5B  Downtown Toronto
# 16      17         M5B  Downtown Toronto
# 17      18         M6B        North York
# 18      19         M7B      Not assigned
# 19      20         M8B      Not assigned
# 20      21         M9B         Etobicoke
# 21      22         M9B         Etobicoke
# 22      23         M9B         Etobicoke
# 23      24         M9B         Etobicoke
# 24      25         M9B         Etobicoke
# 25      26         M1C       Scarborough
# 26      27         M1C       Scarborough
# 27      28         M1C       Scarborough
# 28      29         M2C      Not assigned
# 29      30         M3C        North York
# ..     ...         ...               ...
# 256    257         M9X      Not assigned
# 257    258         M1Y      Not assigned
# 258    259         M2Y      Not assigned
# 259    260         M3Y      Not assigned
# 260    261         M4Y  Downtown Toronto
# 261    262         M5Y      Not assigned
# 262    263         M6Y      Not assigned
# 263    264         M7Y      East Toronto
# 264    265         M8Y         Etobicoke
# 265    266         M8Y         Etobicoke
# 266    267         M8Y         Etobicoke
# 267    268         M8Y         Etobicoke
# 268    269         M8Y         Etobicoke
# 269    270         M8Y         Etobicoke
# 270    271         M8Y         Etobicoke
# 271    272         M8Y         Etobicoke
# 272    273         M9Y      Not assigned
# 273    274         M1Z      Not assigned
# 274    275         M2Z      Not assigned
# 275    276         M3Z      Not assigned
# 276    277         M4Z      Not assigned
# 277    278         M5Z      Not assigned
# 278    279         M6Z      Not assigned
# 279    280         M7Z      Not assigned
# 280    281         M8Z         Etobicoke
# 281    282         M8Z         Etobicoke
# 282    283         M8Z         Etobicoke
# 283    284         M8Z         Etobicoke
# 284    285         M8Z         Etobicoke
# 285    286         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                            Parkwoods
# 2                                     Victoria Village
# 3                                         Harbourfront
# 4                                     Lawrence Heights
# 5                                       Lawrence Manor
# 6                                         Queen's Park
# 7                                         Not assigned
# 8                                         Not assigned
# 9                                                Rouge
# 10                                             Malvern
# 11                                        Not assigned
# 12                                     Don Mills North
# 13                                    Woodbine Gardens
# 14                                       Parkview Hill
# 15                                             Ryerson
# 16                                     Garden District
# 17                                           Glencairn
# 18                                        Not assigned
# 19                                        Not assigned
# 20                                          Cloverdale
# 21                                           Islington
# 22                                        Martin Grove
# 23                                    Princess Gardens
# 24                                     West Deane Park
# 25                                      Highland Creek
# 26                                          Rouge Hill
# 27                                          Port Union
# 28                                        Not assigned
# 29                                     Flemingdon Park
# ..                                                 ...
# 256                                       Not assigned
# 257                                       Not assigned
# 258                                       Not assigned
# 259                                       Not assigned
# 260                               Church and Wellesley
# 261                                       Not assigned
# 262                                       Not assigned
# 263  Business Reply Mail Processing Centre 969 Eastern
# 264                                         Humber Bay
# 265                                   King's Mill Park
# 266                           Kingsway Park South East
# 267                                          Mimico NE
# 268                                     Old Mill South
# 269                                 The Queensway East
# 270                              Royal York South East
# 271                                           Sunnylea
# 272                                       Not assigned
# 273                                       Not assigned
# 274                                       Not assigned
# 275                                       Not assigned
# 276                                       Not assigned
# 277                                       Not assigned
# 278                                       Not assigned
# 279                                       Not assigned
# 280                           Kingsway Park South West
# 281                                          Mimico NW
# 282                                 The Queensway West
# 283                              Royal York South West
# 284                                     South of Bloor
# 285                                       Not assigned
#
# [286 rows x 4 columns]

# %%
df.drop(df[df['Borough']=="Not assigned"].index,axis=0, inplace=True)

# %%
df1=df.groupby("Postal Code").agg(lambda x:','.join(set(x)))

df1.loc[df1['Neighbourhood']=="Not assigned",'Neighbourhood']=df1.loc[df1['Neighbourhood']=="Not assigned",'Borough']

df1.shape
# Out:
# (103, 2)

# %%
# !wget -q -O 'Toronto_long_lat_data.csv'  http://cocl.us/Geospatial_data

# %%
df_lon_lat = pd.read_csv('Toronto_long_lat_data.csv')
df_lon_lat.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
Toronto_df = pd.merge(df1,
                 df_lon_lat[['Postal Code','Latitude', 'Longitude']],
                 on='Postal Code')
Toronto_df.head()
# Out:
#   Postal Code      Borough                         Neighbourhood   Latitude  \
# 0         M1B  Scarborough                         Rouge,Malvern  43.806686
# 1         M1C  Scarborough  Port Union,Rouge Hill,Highland Creek  43.784535
# 2         M1E  Scarborough       West Hill,Guildwood,Morningside  43.763573
# 3         M1G  Scarborough                                Woburn  43.770992
# 4         M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476
